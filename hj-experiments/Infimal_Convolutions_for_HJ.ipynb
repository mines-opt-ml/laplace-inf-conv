# %%
import torch
import numpy as np
import sys
import os

device = 'cpu'
p = 2
save_dir = 'HJ_residuals/'

# %%
save_dir
# Out:
# 'HJ_residuals/'

# %%
def get_inf_convolution(xt, f, g, delta, domain, int_samples, alpha=1, linesearch_iters=0):
  # Compute argmin formula for infimal convolution tailored to HJ equations
  # This approach uses uniform sampling
  # Inputs:
  #   xt: tensor of size dim+1 by 1, where dim = spatial dimension

  assert(xt.shape[1]==1)
  linesearch_iters +=1

  # n_inputs = xt.shape[0]
  dim = xt.shape[0]-1

  x = xt[0:dim]
  t = xt[dim]

  y = (domain[1]-domain[0])*torch.rand(int_samples,dim, device=device) + domain[0]


  argmin_output = torch.zeros(dim, device=device)
  min_output = torch.zeros(1, device=device)

  # both values below are of size n_samples
  g_val = g(y, x, t)
  f_val = f(y)

  assert(g_val.shape==f_val.shape)

  z = -(alpha/delta)*(f_val + g_val) # shape =  n_samples
  w = torch.softmax(z, dim=0) # shape = n_samples

  assert(z.shape==w.shape)

  softmax_overflow_check = (w < np.inf)

  if softmax_overflow_check.prod()==0.0:
    print('xt = ', xt)
    print('z = ', z)
    print('w = ', w)
    alpha = 0.5*alpha
    return get_inf_convolution(x, t, f, delta=delta, int_samples=int_samples, alpha=alpha, linesearch_iters=linesearch_iters, device=device)
  else:
    prox_term = torch.matmul(w.t(), y)
    prox_term = prox_term.view(-1,1)

    prox_overflow = (prox_term < np.inf)
    if prox_overflow.prod() == 0.0:
      print('prox overflowed: ', prox_term)
    assert(prox_overflow.prod() == 1.0)

    min_output = f(prox_term.view(1,-1)) + g(prox_term.view(1,-1), x,t)

    assert(min_output<np.inf)
    assert(np.isnan(min_output.item())==False)

  return min_output, argmin_output, linesearch_iters

# %%
def f(y):
  # size of y is n_samples x n_dim
  return torch.norm(y, dim=1, p=1)

def g(y,x,t,p=p):
  # assumes x has shape n_dim,1
  # assumes y has shape n_samples by n_dim

  if p < np.infty:
    v = torch.abs((y-x.view(-1))/t)

    H_star = (p-1)/p * torch.sum(v**(p/(p-1)), dim=1)

    return t*H_star

def H(u, p=p):
  # assumes p is of size dim x 1
  if p < np.infty:
    return (torch.norm(u, p=p, dim=0)/(p**(1/p)))**p

def compute_HJ_residual(xt, H, domain, f, g, delta, int_samples):

  # assumes input xt is of shape dim+1 x 1

  HJ_res = 0.0
  xt.requires_grad=True

  dim = xt.shape[0]-1
  u_val, prox_term, linesearch_iters = get_inf_convolution(xt, f, g, delta, domain, int_samples)

  grad_u_full = torch.autograd.grad(outputs=u_val, inputs=xt, grad_outputs=torch.ones(u_val.shape, device=device), retain_graph=None, create_graph=True, only_inputs=True, allow_unused=False, is_grads_batched=False)[0]

  u_t = grad_u_full[dim,:].detach().view(1,-1)
  grad_u = grad_u_full[0:dim, :].detach().view(dim, -1)

  xt = xt.detach()

  H_term = H(grad_u)
  HJ_res = u_t + H_term

  return HJ_res

# %%
int_samples = int(1e5)
n_input_samples = int(1e3)
dim = 5

n_trials = 50

t_array = torch.rand(n_input_samples, device=device) + 1e-1

xt_array = 10*torch.rand(dim+1, n_input_samples, device=device)-5 # get samples from [-1,1]
xt_array[dim,:] = t_array

domain = [-10,10]
delta_array = [1e2, 1e1, 1e0, 1e-1, 1e-2]
samples_array = [1e1, 1e2, 1e3, 1e4, 1e5]

HJ_residual_norms = torch.zeros(n_trials, len(delta_array), len(samples_array))

for k in range(n_trials):
  print('\ntrial ', k+1)
  for i in range(len(delta_array)):
    current_delta = delta_array[i]

    max_ls_iters = 1

    print('\n')
    for l in range(len(samples_array)):

      current_int_samples = int(samples_array[l])

      for j in range(n_input_samples):

        xt = xt_array[:, j]
        xt = xt.view(-1, 1)

        inf_terms, prox_terms, linesearch_iters = get_inf_convolution(xt, f, g, current_delta, domain, current_int_samples)
        max_ls_iters = np.max([max_ls_iters, linesearch_iters])

        HJ_residuals = compute_HJ_residual(xt, H, domain, f, g, current_delta, current_int_samples).cpu()
        HJ_residual_norms[k,i,l] = HJ_residual_norms[k,i,l] + torch.norm(HJ_residuals, p=2)/n_input_samples

      print('delta: ', current_delta, ', num samples:', current_int_samples, ', HJ_res norms: ', HJ_residual_norms[k,i,l], ', ls_iters: ', max_ls_iters)
# Out:
# trial  1
#
#
# delta:  100.0 , num samples: 10 , HJ_res norms:  tensor(157.2915) , ls_iters:  1
# delta:  100.0 , num samples: 100 , HJ_res norms:  tensor(20.7180) , ls_iters:  1
# delta:  100.0 , num samples: 1000 , HJ_res norms:  tensor(8.9706) , ls_iters:  1
# delta:  100.0 , num samples: 10000 , HJ_res norms:  tensor(9.4493) , ls_iters:  1
# delta:  100.0 , num samples: 100000 , HJ_res norms:  tensor(9.6992) , ls_iters:  1
#
#
# delta:  10.0 , num samples: 10 , HJ_res norms:  tensor(5984.5649) , ls_iters:  1
# delta:  10.0 , num samples: 100 , HJ_res norms:  tensor(667.9370) , ls_iters:  1
# delta:  10.0 , num samples: 1000 , HJ_res norms:  tensor(36.5180) , ls_iters:  1
# delta:  10.0 , num samples: 10000 , HJ_res norms:  tensor(5.8470) , ls_iters:  1
# delta:  10.0 , num samples: 100000 , HJ_res norms:  tensor(1.1043) , ls_iters:  1
#
#
# delta:  1.0 , num samples: 10 , HJ_res norms:  tensor(131893.7969) , ls_iters:  1
# delta:  1.0 , num samples: 100 , HJ_res norms:  tensor(9479.0684) , ls_iters:  1
# delta:  1.0 , num samples: 1000 , HJ_res norms:  tensor(1671.8214) , ls_iters:  1
# delta:  1.0 , num samples: 10000 , HJ_res norms:  tensor(162.9670) , ls_iters:  1
# delta:  1.0 , num samples: 100000 , HJ_res norms:  tensor(25.1023) , ls_iters:  1
#
#
# delta:  0.1 , num samples: 10 , HJ_res norms:  tensor(20731.8262) , ls_iters:  1
# delta:  0.1 , num samples: 100 , HJ_res norms:  tensor(66144.7578) , ls_iters:  1
# delta:  0.1 , num samples: 1000 , HJ_res norms:  tensor(53508.5859) , ls_iters:  1
# delta:  0.1 , num samples: 10000 , HJ_res norms:  tensor(2392.5923) , ls_iters:  1
# delta:  0.1 , num samples: 100000 , HJ_res norms:  tensor(328.4394) , ls_iters:  1
#
#
# delta:  0.01 , num samples: 10 , HJ_res norms:  tensor(0.1106) , ls_iters:  1
# delta:  0.01 , num samples: 100 , HJ_res norms:  tensor(37582.9180) , ls_iters:  1
# delta:  0.01 , num samples: 1000 , HJ_res norms:  tensor(191355.3906) , ls_iters:  1
# delta:  0.01 , num samples: 10000 , HJ_res norms:  tensor(1384.4032) , ls_iters:  1
# delta:  0.01 , num samples: 100000 , HJ_res norms:  tensor(3376.0464) , ls_iters:  1
#
# trial  2
#
#
# delta:  100.0 , num samples: 10 , HJ_res norms:  tensor(119.0721) , ls_iters:  1
# delta:  100.0 , num samples: 100 , HJ_res norms:  tensor(21.1864) , ls_iters:  1
# delta:  100.0 , num samples: 1000 , HJ_res norms:  tensor(8.9024) , ls_iters:  1
# delta:  100.0 , num samples: 10000 , HJ_res norms:  tensor(9.4987) , ls_iters:  1
# delta:  100.0 , num samples: 100000 , HJ_res norms:  tensor(9.7108) , ls_iters:  1
#
#
# delta:  10.0 , num samples: 10 , HJ_res norms:  tensor(10348.3125) , ls_iters:  1
# delta:  10.0 , num samples: 100 , HJ_res norms:  tensor(547.8043) , ls_iters:  1
# delta:  10.0 , num samples: 1000 , HJ_res norms:  tensor(50.5844) , ls_iters:  1
# delta:  10.0 , num samples: 10000 , HJ_res norms:  tensor(6.6742) , ls_iters:  1
# delta:  10.0 , num samples: 100000 , HJ_res norms:  tensor(1.0593) , ls_iters:  1
#
#
# delta:  1.0 , num samples: 10 , HJ_res norms:  tensor(30795.3340) , ls_iters:  1
# delta:  1.0 , num samples: 100 , HJ_res norms:  tensor(3873.6880) , ls_iters:  1
# delta:  1.0 , num samples: 1000 , HJ_res norms:  tensor(2918.5208) , ls_iters:  1
# delta:  1.0 , num samples: 10000 , HJ_res norms:  tensor(187.8114) , ls_iters:  1
# delta:  1.0 , num samples: 100000 , HJ_res norms:  tensor(7.7584) , ls_iters:  1
#
#
# delta:  0.1 , num samples: 10 , HJ_res norms:  tensor(11330.4922) , ls_iters:  1
# delta:  0.1 , num samples: 100 , HJ_res norms:  tensor(18432.9141) , ls_iters:  1
# delta:  0.1 , num samples: 1000 , HJ_res norms:  tensor(16352.7578) , ls_iters:  1
# delta:  0.1 , num samples: 10000 , HJ_res norms:  tensor(1420.3152) , ls_iters:  1
# delta:  0.1 , num samples: 100000 , HJ_res norms:  tensor(132.7208) , ls_iters:  1
#
#
# delta:  0.01 , num samples: 10 , HJ_res norms:  tensor(86078.1016) , ls_iters:  1
# delta:  0.01 , num samples: 100 , HJ_res norms:  tensor(755801.0625) , ls_iters:  1
# delta:  0.01 , num samples: 1000 , HJ_res norms:  tensor(748.5479) , ls_iters:  1
# delta:  0.01 , num samples: 10000 , HJ_res norms:  tensor(1545.2527) , ls_iters:  1
# delta:  0.01 , num samples: 100000 , HJ_res norms:  tensor(3277.3647) , ls_iters:  1
#
# trial  3
#
#
# delta:  100.0 , num samples: 10 , HJ_res norms:  tensor(126.0100) , ls_iters:  1
# delta:  100.0 , num samples: 100 , HJ_res norms:  tensor(20.1414) , ls_iters:  1
# delta:  100.0 , num samples: 1000 , HJ_res norms:  tensor(9.0881) , ls_iters:  1
# delta:  100.0 , num samples: 10000 , HJ_res norms:  tensor(9.5030) , ls_iters:  1
# delta:  100.0 , num samples: 100000 , HJ_res norms:  tensor(9.7069) , ls_iters:  1
#
#
# delta:  10.0 , num samples: 10 , HJ_res norms:  tensor(3021.9917) , ls_iters:  1
# delta:  10.0 , num samples: 100 , HJ_res norms:  tensor(786.4724) , ls_iters:  1
# delta:  10.0 , num samples: 1000 , HJ_res norms:  tensor(54.9692) , ls_iters:  1
# delta:  10.0 , num samples: 10000 , HJ_res norms:  tensor(5.2576) , ls_iters:  1
# delta:  10.0 , num samples: 100000 , HJ_res norms:  tensor(1.0809) , ls_iters:  1
#
#
# delta:  1.0 , num samples: 10 , HJ_res norms:  tensor(36919.6367) , ls_iters:  1
# delta:  1.0 , num samples: 100 , HJ_res norms:  tensor(47932.8438) , ls_iters:  1
# delta:  1.0 , num samples: 1000 , HJ_res norms:  tensor(1154.3547) , ls_iters:  1
# delta:  1.0 , num samples: 10000 , HJ_res norms:  tensor(324.9572) , ls_iters:  1
# delta:  1.0 , num samples: 100000 , HJ_res norms:  tensor(23.0255) , ls_iters:  1
#
#
# delta:  0.1 , num samples: 10 , HJ_res norms:  tensor(36829.1914) , ls_iters:  1
# delta:  0.1 , num samples: 100 , HJ_res norms:  tensor(285345.5312) , ls_iters:  1
# delta:  0.1 , num samples: 1000 , HJ_res norms:  tensor(6883.0176) , ls_iters:  1
# delta:  0.1 , num samples: 10000 , HJ_res norms:  tensor(2605.8391) , ls_iters:  1
# delta:  0.1 , num samples: 100000 , HJ_res norms:  tensor(173.0822) , ls_iters:  1
#
#
# delta:  0.01 , num samples: 10 , HJ_res norms:  tensor(0.0641) , ls_iters:  1
# delta:  0.01 , num samples: 100 , HJ_res norms:  tensor(11461.0234) , ls_iters:  1
# delta:  0.01 , num samples: 1000 , HJ_res norms:  tensor(13826.9854) , ls_iters:  1
# delta:  0.01 , num samples: 10000 , HJ_res norms:  tensor(26205.5293) , ls_iters:  1
# delta:  0.01 , num samples: 100000 , HJ_res norms:  tensor(1126.0179) , ls_iters:  1
#
# trial  4
#
#
# delta:  100.0 , num samples: 10 , HJ_res norms:  tensor(142.0162) , ls_iters:  1
# delta:  100.0 , num samples: 100 , HJ_res norms:  tensor(22.2380) , ls_iters:  1
# delta:  100.0 , num samples: 1000 , HJ_res norms:  tensor(8.7637) , ls_iters:  1
# delta:  100.0 , num samples: 10000 , HJ_res norms:  tensor(9.4637) , ls_iters:  1
# delta:  100.0 , num samples: 100000 , HJ_res norms:  tensor(9.6926) , ls_iters:  1
#
#
# delta:  10.0 , num samples: 10 , HJ_res norms:  tensor(4020.0071) , ls_iters:  1
# delta:  10.0 , num samples: 100 , HJ_res norms:  tensor(608.3825) , ls_iters:  1
# delta:  10.0 , num samples: 1000 , HJ_res norms:  tensor(45.3268) , ls_iters:  1
# delta:  10.0 , num samples: 10000 , HJ_res norms:  tensor(6.1557) , ls_iters:  1
# delta:  10.0 , num samples: 100000 , HJ_res norms:  tensor(1.1154) , ls_iters:  1
#
#
# delta:  1.0 , num samples: 10 , HJ_res norms:  tensor(23173.9883) , ls_iters:  1
# delta:  1.0 , num samples: 100 , HJ_res norms:  tensor(17036.8691) , ls_iters:  1
# delta:  1.0 , num samples: 1000 , HJ_res norms:  tensor(1793.5231) , ls_iters:  1
# delta:  1.0 , num samples: 10000 , HJ_res norms:  tensor(203.6485) , ls_iters:  1
# delta:  1.0 , num samples: 100000 , HJ_res norms:  tensor(17.6872) , ls_iters:  1
#
#
# delta:  0.1 , num samples: 10 , HJ_res norms:  tensor(1114993.3750) , ls_iters:  1
# delta:  0.1 , num samples: 100 , HJ_res norms:  tensor(134510.6719) , ls_iters:  1
# delta:  0.1 , num samples: 1000 , HJ_res norms:  tensor(13049.9385) , ls_iters:  1
# delta:  0.1 , num samples: 10000 , HJ_res norms:  tensor(1410.8239) , ls_iters:  1
# delta:  0.1 , num samples: 100000 , HJ_res norms:  tensor(270.0561) , ls_iters:  1
#
#
# delta:  0.01 , num samples: 10 , HJ_res norms:  tensor(0.7077) , ls_iters:  1
# delta:  0.01 , num samples: 100 , HJ_res norms:  tensor(42931.8242) , ls_iters:  1
# delta:  0.01 , num samples: 1000 , HJ_res norms:  tensor(38032.3828) , ls_iters:  1
# delta:  0.01 , num samples: 10000 , HJ_res norms:  tensor(731.0601) , ls_iters:  1
# delta:  0.01 , num samples: 100000 , HJ_res norms:  tensor(2386.9199) , ls_iters:  1
#
# trial  5
#
#
# delta:  100.0 , num samples: 10 , HJ_res norms:  tensor(125.9389) , ls_iters:  1
# delta:  100.0 , num samples: 100 , HJ_res norms:  tensor(20.2350) , ls_iters:  1
# delta:  100.0 , num samples: 1000 , HJ_res norms:  tensor(9.0016) , ls_iters:  1
# delta:  100.0 , num samples: 10000 , HJ_res norms:  tensor(9.4897) , ls_iters:  1
# delta:  100.0 , num samples: 100000 , HJ_res norms:  tensor(9.7166) , ls_iters:  1
#
#
# delta:  10.0 , num samples: 10 , HJ_res norms:  tensor(5312.3184) , ls_iters:  1
# delta:  10.0 , num samples: 100 , HJ_res norms:  tensor(475.9380) , ls_iters:  1
# delta:  10.0 , num samples: 1000 , HJ_res norms:  tensor(48.0768) , ls_iters:  1
# delta:  10.0 , num samples: 10000 , HJ_res norms:  tensor(6.1228) , ls_iters:  1
# delta:  10.0 , num samples: 100000 , HJ_res norms:  tensor(1.1558) , ls_iters:  1
#
#
# delta:  1.0 , num samples: 10 , HJ_res norms:  tensor(31946.0801) , ls_iters:  1
# delta:  1.0 , num samples: 100 , HJ_res norms:  tensor(8949.8994) , ls_iters:  1
# delta:  1.0 , num samples: 1000 , HJ_res norms:  tensor(1005.5277) , ls_iters:  1
# delta:  1.0 , num samples: 10000 , HJ_res norms:  tensor(109.2765) , ls_iters:  1
# delta:  1.0 , num samples: 100000 , HJ_res norms:  tensor(14.7783) , ls_iters:  1
#
#
# delta:  0.1 , num samples: 10 , HJ_res norms:  tensor(9006.2568) , ls_iters:  1
# delta:  0.1 , num samples: 100 , HJ_res norms:  tensor(8510.9766) , ls_iters:  1
# delta:  0.1 , num samples: 1000 , HJ_res norms:  tensor(11231.6465) , ls_iters:  1
# delta:  0.1 , num samples: 10000 , HJ_res norms:  tensor(2747.2549) , ls_iters:  1
# delta:  0.1 , num samples: 100000 , HJ_res norms:  tensor(611.7346) , ls_iters:  1
#
#
# delta:  0.01 , num samples: 10 , HJ_res norms:  tensor(990045.4375) , ls_iters:  1
# delta:  0.01 , num samples: 100 , HJ_res norms:  tensor(132093.3906) , ls_iters:  1
# delta:  0.01 , num samples: 1000 , HJ_res norms:  tensor(5094.4375) , ls_iters:  1
# delta:  0.01 , num samples: 10000 , HJ_res norms:  tensor(1642.2640) , ls_iters:  1
# delta:  0.01 , num samples: 100000 , HJ_res norms:  tensor(6616.6035) , ls_iters:  1
#
# trial  6
#
#
# delta:  100.0 , num samples: 10 , HJ_res norms:  tensor(151.8320) , ls_iters:  1
# delta:  100.0 , num samples: 100 , HJ_res norms:  tensor(20.8982) , ls_iters:  1
# delta:  100.0 , num samples: 1000 , HJ_res norms:  tensor(9
, ls_iters:  1
# delta:  1.0 , num samples: 100000 , HJ_res norms:  tensor(17.1617) , ls_iters:  1
#
#
# delta:  0.1 , num samples: 10 , HJ_res norms:  tensor(133222.7188) , ls_iters:  1
# delta:  0.1 , num samples: 100 , HJ_res norms:  tensor(47655.5664) , ls_iters:  1
# delta:  0.1 , num samples: 1000 , HJ_res norms:  tensor(3988.2842) , ls_iters:  1
# delta:  0.1 , num samples: 10000 , HJ_res norms:  tensor(5491.1865) , ls_iters:  1
# delta:  0.1 , num samples: 100000 , HJ_res norms:  tensor(346.6794) , ls_iters:  1
#
#
# delta:  0.01 , num samples: 10 , HJ_res norms:  tensor(755717.8750) , ls_iters:  1
# delta:  0.01 , num samples: 100 , HJ_res norms:  tensor(1399.2419) , ls_iters:  1
# delta:  0.01 , num samples: 1000 , HJ_res norms:  tensor(21243.1113) , ls_iters:  1
# delta:  0.01 , num samples: 10000 , HJ_res norms:  tensor(73799.3203) , ls_iters:  1
# delta:  0.01 , num samples: 100000 , HJ_res norms:  tensor(1915.7985) , ls_iters:  1
#
# trial  50
#
#
# delta:  100.0 , num samples: 10 , HJ_res norms:  tensor(102.9390) , ls_iters:  1
# delta:  100.0 , num samples: 100 , HJ_res norms:  tensor(23.3190) , ls_iters:  1
# delta:  100.0 , num samples: 1000 , HJ_res norms:  tensor(8.9215) , ls_iters:  1
# delta:  100.0 , num samples: 10000 , HJ_res norms:  tensor(9.4749) , ls_iters:  1
# delta:  100.0 , num samples: 100000 , HJ_res norms:  tensor(9.6972) , ls_iters:  1
#
#
# delta:  10.0 , num samples: 10 , HJ_res norms:  tensor(8798.1963) , ls_iters:  1
# delta:  10.0 , num samples: 100 , HJ_res norms:  tensor(600.3008) , ls_iters:  1
# delta:  10.0 , num samples: 1000 , HJ_res norms:  tensor(66.4096) , ls_iters:  1
# delta:  10.0 , num samples: 10000 , HJ_res norms:  tensor(5.9834) , ls_iters:  1
# delta:  10.0 , num samples: 100000 , HJ_res norms:  tensor(1.0263) , ls_iters:  1
#
#
# delta:  1.0 , num samples: 10 , HJ_res norms:  tensor(30780.4668) , ls_iters:  1
# delta:  1.0 , num samples: 100 , HJ_res norms:  tensor(13684.1934) , ls_iters:  1
# delta:  1.0 , num samples: 1000 , HJ_res norms:  tensor(1327.9316) , ls_iters:  1
# delta:  1.0 , num samples: 10000 , HJ_res norms:  tensor(185.7907) , ls_iters:  1
# delta:  1.0 , num samples: 100000 , HJ_res norms:  tensor(18.8626) , ls_iters:  1
#
#
# delta:  0.1 , num samples: 10 , HJ_res norms:  tensor(23886.4141) , ls_iters:  1
# delta:  0.1 , num samples: 100 , HJ_res norms:  tensor(26386.8027) , ls_iters:  1
# delta:  0.1 , num samples: 1000 , HJ_res norms:  tensor(10345.3096) , ls_iters:  1
# delta:  0.1 , num samples: 10000 , HJ_res norms:  tensor(1917.6196) , ls_iters:  1
# delta:  0.1 , num samples: 100000 , HJ_res norms:  tensor(493.0237) , ls_iters:  1
#
#
# delta:  0.01 , num samples: 10 , HJ_res norms:  tensor(1173204.3750) , ls_iters:  1
# delta:  0.01 , num samples: 100 , HJ_res norms:  tensor(2052.9312) , ls_iters:  1
# delta:  0.01 , num samples: 1000 , HJ_res norms:  tensor(1815.4604) , ls_iters:  1
# delta:  0.01 , num samples: 10000 , HJ_res norms:  tensor(6289.1470) , ls_iters:  1
# delta:  0.01 , num samples: 100000 , HJ_res norms:  tensor(7285.1299) , ls_iters:  1

# %%
data_name = 'hj_residuals_p' + str(p) + '_dim' + str(int(dim)) + '.pth'
file_name = save_dir + data_name
state = {
    'HJ_residual_norms': HJ_residual_norms,
    'n_input_samples': n_input_samples,
    'dim': dim,
    'xt_array': xt_array,
    'delta_array': delta_array,
    'samples_array': samples_array,
    'domain': domain,
    'n_trials': n_trials
}
torch.save(state, file_name)
print('files saved to ' + file_name)
# Out:
# files saved to HJ_residuals/hj_residuals_p2_dim5.pth
